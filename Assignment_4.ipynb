# %%
1. What exactly is []?
Ans. Empty list


2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third 
value? (Assume [2, 4, 6, 8, 10] are in spam.)
Ans. 
spam=[2, 4, 6, 8, 10]
spam[2]="hello"


Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
spam=['a', 'b', 'c', 'd']

3. What is the value of spam[int(int('3' * 2) / 11)]?
Ans. 'd'


4. What is the value of spam[-1]?
Ans. 'd'


5. What is the value of spam[:2]?
Ans. ['a', 'b']


Let's pretend bacon has the list [3.14, 'cat', 11, 'cat', True] for the next three questions.
bacon=[3.14, 'cat', 11, 'cat', True]

6. What is the value of bacon.index('cat')?
Ans. 1


7. How does bacon.append(99) change the look of the list value in bacon?
Ans. It adds another element 99 (with int datatype) to the end of the list bacon.
[3.14, 'cat', 11, 'cat', True, 99]


8. How does bacon.remove('cat') change the look of the list in bacon?
Ans. It removes the first appearance of element cat(str datatype) from the existing list.
[3.14, 11, 'cat', True, 99]


9. What are the list concatenation and list replication operators?
Ans. 
l1 = [2,3]
l2 = [1,4]

# list concatination
l1+l2
[2, 3, 1, 4]

# list replication
l1*3
[2,3,2,3,2,3]


10. What is difference between the list methods append() and insert()?
Ans. Append adds the desired element automatically at the last index of the list whereas in insert we have to provide the 
index position and it adds the element before that index & shifts the exisitng element further.

#append
l1 = [2,3,5,1]
100
l1.append(100)
l1
[2, 3, 5, 1, 100]

#insert
l1.insert(2,100)
l1
[2, 3, 100, 5, 1, 100]


11. What are the two methods for removing items from a list?
Ans. pop() & remove()

#pop
l1 = [2,3,5,1]
l1.pop()
100
l1
[2, 3, 100, 5, 1]

#remove
l1 = [2,3,5,1]
l1.remove(5)
l1
[2, 3, 1]



12. Describe how list values and string values are identical.
Ans. 
a. Both list & strings are iterables which can be converted to iterator & can be iterate upon. 
b. We can use both of them in for loop which internally performs the same task of iteration (Next, Iter). 
c. Also both can be used for slicing operations & concatenation, repetetion in same manner.


13. What's the difference between tuples and lists?
Ans.
Tuples are immutable whereas lists are mutable.
Tupes are having parenthesis whereas lists are having square bracket.

14. How do you type a tuple value that only contains the integer 42?
Ans.
a=(42,)
type(a)
tuple

15. How do you get a list value's tuple form? How do you get a tuple value's list form?
Ans.
#list value's tuple form
l1 = [2,3]
l = tuple(l1)
l
(2, 3)

#tuple value's list form
t1 = (3,4)
t = list(t1)
t
[3, 4]


16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
Ans. 
They contain references to list values


17. How do you distinguish between copy.copy() and copy.deepcopy()?
Ans. 
The copy.copy() function will do a shallow copy of a list,
The copy.deepcopy() function will do a deep copy of a list. only copy.deepcopy() will duplicate any lists inside the list
